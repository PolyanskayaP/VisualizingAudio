# %%
# for data transformation
import numpy as np
# for visualizing the data
import matplotlib.pyplot as plt
# for opening the media file
import scipy.io.wavfile as wavfile

# %% [markdown]
# https://audio.online-convert.com/ru/convert-to-wav
#
# https://dolby.io/blog/beginners-guide-to-visualizing-audio-as-a-spectogram-in-python/

# %%
Fs, aud = wavfile.read('/kaggle/input/wav-song/Tarkan_-_Ayrlk_Zor_Orjinal_Versiyon_65358515.wav')
# select left channel only
aud = aud[:,0]
# trim the first 125 seconds
first = aud[:int(Fs*125)]

# %%
powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(first, Fs=Fs)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7774: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
Fs, aud = wavfile.read('/kaggle/input/wav-song/Mari_aka_Krajjmbreri_-_Domovojj_76654122.wav')
# select left channel only
aud = aud[:,0]
# trim the first 125 seconds
first = aud[:int(Fs*125)]

# %%
powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(first, Fs=Fs)
plt.show()
